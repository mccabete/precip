# %%
! pip install -e .
# Out:
# Obtaining file:///home/jovyan/Precipitation_paper
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: precip_helper
#   Building editable for precip_helper (pyproject.toml) ... done
#   Created wheel for precip_helper: filename=precip_helper-0.1.0-0.editable-py3-none-any.whl size=1298 sha256=e49fe002b8ddf49bfe8bca474f8975becec93ae06e0bcd3ff41371415291bbe9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1m45z2d8/wheels/0d/d8/f6/0e90ec4164bf3c02bf3bed8ede68ddfb64e3b2ef0023ebb734
# Successfully built precip_helper
# Installing collected packages: precip_helper
#   Attempting uninstall: precip_helper
#     Found existing installation: precip_helper 0.1.0
#     Uninstalling precip_helper-0.1.0:
#       Successfully uninstalled precip_helper-0.1.0
# Successfully installed precip_helper-0.1.0

# %%
import xarray as xr
import earthaccess
import boto3
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import warnings
from IPython.display import display, Markdown
import pandas as pd
import geopandas as gpd
import rasterio
import datetime
import pyarrow as pa
import pyarrow.parquet as pq
import os
import numpy as np

warnings.filterwarnings('ignore')
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2


from precip_helper.utils import read_in_fires_and_precip

# %%
fires = read_in_fires_and_precip()

fires = fires[fires.l1_ecoregion != "GREAT PLAINS"]
